# %%
import pandas as pd

data = pd.read_csv("data/gapminder_gdp_europe.csv", index_col="country")
data
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
print(data.loc["Albania", "gdpPercap_1952"])
# Out:
# 1601.056136

# %%
print(data.loc["Albania"])
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# gdpPercap_1977    3533.003910
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# Name: Albania, dtype: float64

# %%
# All get a single column
print(data.loc[:, "gdpPercap_1952"])
print(data["gdpPercap_1952"])
print(data.gdpPercap_1952)
# Out:
# country
# Albania                    1601.056136
# Austria                    6137.076492
# Belgium                    8343.105127
# Bosnia and Herzegovina      973.533195
# Bulgaria                   2444.286648
# Croatia                    3119.236520
# Czech Republic             6876.140250
# Denmark                    9692.385245
# Finland                    6424.519071
# France                     7029.809327
# Germany                    7144.114393
# Greece                     3530.690067
# Hungary                    5263.673816
# Iceland                    7267.688428
# Ireland                    5210.280328
# Italy                      4931.404155
# Montenegro                 2647.585601
# Netherlands                8941.571858
# Norway                    10095.421720
# Poland                     4029.329699
# Portugal                   3068.319867
# Romania                    3144.613186
# Serbia                     3581.459448
# Slovak Republic            5074.659104
# ...

# %%
print(data.loc["Italy":"Poland", 'gdpPercap_1962':"gdpPercap_1972"])
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
print(data.loc["Italy":"Poland", 'gdpPercap_1962':"gdpPercap_1972"].min())
# Out:
# gdpPercap_1962    4649.593785
# gdpPercap_1967    5907.850937
# gdpPercap_1972    7778.414017
# dtype: float64

# %%
subset = data.loc["Italy":"Poland", 'gdpPercap_1962':"gdpPercap_1972"]
print("subset:\n", subset)

print("numbers are large?\n", subset > 10000)
# Out:
# subset:
#               gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993
# numbers are large?
#               gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %%
print("Hello\n\nI\nam\nnew")
# Out:
# Hello
#
# I
# am
# new

# %%
mask = subset > 10000
print(subset[mask].describe())
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        2.000000        3.000000        3.000000
# mean     13120.625535    13915.843047    16676.358320
# std        466.373656     3408.589070     3817.597015
# min      12790.849560    10022.401310    12269.273780
# 25%      12955.737547    12692.826335    15532.009725
# 50%      13120.625535    15363.251360    18794.745670
# 75%      13285.513523    15862.563915    18879.900590
# max      13450.401510    16361.876470    18965.055510

# %%
mask_higher = data > data.mean()
wealth_score = mask_higher.aggregate('sum', axis=1)  / len(data.columns)
wealth_score
# Out:
# country
# Albania                   0.000000
# Austria                   1.000000
# Belgium                   1.000000
# Bosnia and Herzegovina    0.000000
# Bulgaria                  0.000000
# Croatia                   0.000000
# Czech Republic            0.500000
# Denmark                   1.000000
# Finland                   1.000000
# France                    1.000000
# Germany                   1.000000
# Greece                    0.333333
# Hungary                   0.000000
# Iceland                   1.000000
# Ireland                   0.333333
# Italy                     0.500000
# Montenegro                0.000000
# Netherlands               1.000000
# Norway                    1.000000
# Poland                    0.000000
# Portugal                  0.000000
# Romania                   0.000000
# Serbia                    0.000000
# Slovak Republic           0.000000
# Slovenia                  0.333333
# Spain                     0.333333
# ...

# %%
data.groupby(wealth_score).sum()
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0.000000    36916.854200    46110.918793    56850.065437    71324.848786
# 0.333333    16790.046878    20942.456800    25744.935321    33567.667670
# 0.500000    11807.544405    14505.000150    18380.449470    21421.846200
# 1.000000   104317.277560   127332.008735   149989.154201   178000.350040
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0.000000    88569.346898   104459.358438   113553.768507   119649.599409
# 0.333333    45277.839976    53860.456750    59679.634020    64436.912960
# 0.500000    25377.727380    29056.145370    31914.712050    35517.678220
# 1.000000   215162.343140   241143.412730   263388.781960   296825.131210
#
#           gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# 0.000000    92380.047256   103772.937598   118590.929863   149577.357928
# 0.333333    67918.093220    80876.051580   102086.795210   122803.729520
# ...

# %%
df = pd.read_csv('data/gapminder_gdp_americas.csv', index_col='country')

# %%
df.head(10)
# Out:
#                    continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina           Americas     5911.315053     6856.856212     7133.166023
# Bolivia             Americas     2677.326347     2127.686326     2180.972546
# Brazil              Americas     2108.944355     2487.365989     3336.585802
# Canada              Americas    11367.161120    12489.950060    13462.485550
# Chile               Americas     3939.978789     4315.622723     4519.094331
# Colombia            Americas     2144.115096     2323.805581     2492.351109
# Costa Rica          Americas     2627.009471     2990.010802     3460.937025
# Cuba                Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic  Americas     1397.717137     1544.402995     1662.137359
# Ecuador             Americas     3522.110717     3780.546651     4086.114078
#
#                     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# ...

# %%
df.tail()
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Puerto Rico          Americas     3081.959785     3907.156189     5108.344630
# Trinidad and Tobago  Americas     3023.271928     4100.393400     4997.523971
# United States        Americas    13990.482080    14847.127120    16173.145860
# Uruguay              Americas     5716.766744     6150.772969     5603.357717
# Venezuela            Americas     7689.799761     9802.466526     8422.974165
#
#                      gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Puerto Rico             6929.277714     9123.041742     9770.524921
# Trinidad and Tobago     5621.368472     6619.551419     7899.554209
# United States          19530.365570    21806.035940    24072.632130
# Uruguay                 5444.619620     5703.408898     6504.339663
# Venezuela               9541.474188    10505.259660    13143.950950
#
# ...

# %%
df.T
# Out:
# country        Argentina   Bolivia    Brazil    Canada     Chile  Colombia  \
# continent       Americas  Americas  Americas  Americas  Americas  Americas
# gdpPercap_1952   5911.32   2677.33   2108.94   11367.2   3939.98   2144.12
# gdpPercap_1957   6856.86   2127.69   2487.37     12490   4315.62   2323.81
# gdpPercap_1962   7133.17   2180.97   3336.59   13462.5   4519.09   2492.35
# gdpPercap_1967   8052.95   2586.89   3429.86   16076.6   5106.65   2678.73
# gdpPercap_1972   9443.04   2980.33   4985.71   18970.6   5494.02   3264.66
# gdpPercap_1977     10079    3548.1   6660.12   22090.9   4756.76   3815.81
# gdpPercap_1982    8997.9   3156.51   7030.84   22898.8   5095.67   4397.58
# gdpPercap_1987   9139.67   2753.69    7807.1   26626.5   5547.06   4903.22
# gdpPercap_1992   9308.42    2961.7   6950.28   26342.9   7596.13   5444.65
# gdpPercap_1997   10967.3   3326.14   7957.98   28954.9   10118.1   6117.36
# ...

# %%
# GDP per capita for each country in 2007 as a multiple of GDP per capita for that country in 1952.

gdp2007 = data.loc[:, "gdpPercap_2007"]
gdp1952 = data.loc[:, "gdpPercap_1952"]
gdp2007 / gdp1952
# Out:
# country
# Albania                   3.708196
# Austria                   5.886596
# Belgium                   4.038377
# Bosnia and Herzegovina    7.648736
# Bulgaria                  4.369697
# Croatia                   4.686795
# Czech Republic            3.320658
# Denmark                   3.639808
# Finland                   5.168805
# France                    4.334402
# Germany                   4.503060
# Greece                    7.799725
# Hungary                   3.421364
# Iceland                   4.978308
# Ireland                   7.806873
# Italy                     5.793425
# Montenegro                3.495221
# Netherlands               4.115376
# Norway                    4.889067
# Poland                    3.819475
# Portugal                  6.684325
# Romania                   3.437140
# Serbia                    2.732555
# Slovak Republic           3.680703
# Slovenia                  6.113405
# Spain                     7.517163
# ...

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       30.000000       30.000000       30.000000       30.000000
# mean      5661.057435     6963.012816     8365.486814    10143.823757
# std       3114.060493     3677.950146     4199.193906     4724.983889
# min        973.533195     1353.989176     1709.683679     2172.352423
# 25%       3241.132406     4394.874315     5373.536612     6657.939047
# 50%       5142.469716     6066.721495     7515.733738     9366.067033
# 75%       7236.794919     9597.220820    10931.085347    13277.182057
# max      14734.232750    17909.489730    20431.092700    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       30.000000       30.000000       30.000000       30.000000
# mean     12479.575246    14283.979110    15617.896551    17214.310727
# std       5509.691411     5874.464896     6453.234827     7482.957960
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
times = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(times, position)
plt.xlabel("Time (hr)")
plt.ylabel('Position (km)')
plt.show()

# %%
data = pd.read_csv('data/gapminder_gdp_oceania.csv', index_col="country")
years = data.columns.str.strip('gdpPercap_')
data.columns = years.astype(int)
data.loc['Australia'].plot()

# %%
data.T.plot()
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')

# %%
years = data.columns
gdp_australia = data.loc["Australia"]
gdp_nz = data.loc["New Zealand"]

plt.plot(years, gdp_australia, 'g--', label="Australia")
plt.plot(years, gdp_nz, 'b-', label="New Zealand")

plt.legend(loc='upper left')
plt.xlabel('Year')
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
plt.scatter(gdp_australia, gdp_nz)

# %%
data.T.plot.scatter('Australia', 'New Zealand')

# %%
data.describe().T.plot(kind="scatter", x="min", y="max")

# %%
# ex 1 after break

df.min().plot(label='min')
df.max().plot(label='max')
plt.legend(loc='best')
plt.xticks(rotation=90)
plt.show()

# %%
data.min().plot(label='min')

# %%
df_all = pd.read_csv('data/gapminder_all.csv', index_col='country')


df_all.plot(kind='scatter', x='gdpPercap_2007', y='lifeExp_2007',
            s=df_all['pop_2007']/1e6, alpha=0.5)
plt.show()

# %%
df_all
# Out:
#                          continent  gdpPercap_1952  gdpPercap_1957  \
# country
# Algeria                     Africa     2449.008185     3013.976023
# Angola                      Africa     3520.610273     3827.940465
# Benin                       Africa     1062.752200      959.601080
# Botswana                    Africa      851.241141      918.232535
# Burkina Faso                Africa      543.255241      617.183465
# Burundi                     Africa      339.296459      379.564628
# Cameroon                    Africa     1172.667655     1313.048099
# Central African Republic    Africa     1071.310713     1190.844328
# Chad                        Africa     1178.665927     1308.495577
# Comoros                     Africa     1102.990936     1211.148548
# Congo Dem. Rep.             Africa      780.542326      905.860230
# Congo Rep.                  Africa     2125.621418     2315.056572
# Cote d'Ivoire               Africa     1388.594732     1500.895925
# ...

# %%
pressures = [0.273, 0.275, 20.79, 20.74]
print("pressures: ", pressures)
print("item number: ", len(pressures))
# Out:
# pressures:  [0.273, 0.275, 20.79, 20.74]
# item number:  4

# %%
print('fourth: ', pressures[3])
# Out:
# zeroth:  20.74

# %%
primes = [2, 3, 5]
print("initial values: ", primes)
primes.append(7)
primes.append(7)
primes.append(7)
print("now has: ", primes)
# Out:
# initial values:  [2, 3, 5]
# now has:  [2, 3, 5, 7, 7, 7]

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
print("initial values: ", primes)
removed = primes.pop(3)
print("now has: ", primes)
print("we removed: ", removed)
# Out:
# initial values:  [2, 3, 5]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-120-4e2c839bcbcc> in <module>
#       1 print("initial values: ", primes)
# ----> 2 removed = primes.pop(3)
#       3 print("now has: ", primes)
#       4 print("we removed: ", removed)
#
# IndexError: pop index out of range

# %%
empty_list = []

# %%
print(empty_list)
# Out:
# []

# %%
goals = [1, 'Create lists.', 2, 'extract items from list', 3, 'profit']

# %%
goals
# Out:
# [1, 'Create lists.', 2, 'extract items from list', 3, 'profit']

# %%
element = 'carbon'
element[99]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-128-e3674e5ca2ed> in <module>
#       1 element = 'carbon'
# ----> 2 element[99]
#
# IndexError: string index out of range

# %%
goals[-1] = 'modify values'

# %%
goals
# Out:
# [1, 'Create lists.', 2, 'extract items from list', 3, 'modify values']

# %%
goals.pop(-1)
# Out:
# 'modify values'

# %%
print('string to list: ', list('tin'))
print('list to string: ', ', '.join(['g', 'o', 'l', 'd']))
# Out:
# string to list:  ['t', 'i', 'n']
# list to string:  g, o, l, d

# %%
element
# carbon
print(goals[::3]) # slices[low:high:stride]
print(goals[::-1]) # slices[low:high:stride]
# Out:
# [1, 'extract items from list']
# [3, 'extract items from list', 2, 'Create lists.', 1]

# %%
letters = list('fold')
sorted_letters = sorted(letters)
print('letters is ', letters, ' and result is', sorted_letters)
# Out:
# letters is  ['f', 'o', 'l', 'd']  and result is ['d', 'f', 'l', 'o']

# %%
letters = list('fold')
sorted_letters = letters.sort()
print('letters is ', letters, ' and result is', sorted_letters)
# Out:
# letters is  ['d', 'f', 'l', 'o']  and result is None

# %%
letters
# Out:
# ['d', 'f', 'l', 'o']

# %%
old = list('gold')
new = old
print('old is ', old)
new[1] = 'f'
print('new is ', new, ' and old is ', old)
# Out:
# old is  ['g', 'o', 'l', 'd']
# new is  ['g', 'f', 'l', 'd']  and old is  ['g', 'f', 'l', 'd']

# %%
old = list('gold')
new = old[:]
new[1] = 'f'
print('new is ', new, ' and old is ', old)
# Out:
# new is  ['g', 'f', 'l', 'd']  and old is  ['g', 'o', 'l', 'd']
